# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading dataset

# %%
# Load the Titanic dataset
df = sns.load_dataset('titanic')

# Display the first few rows of the dataset
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
sns.countplot(df['survived'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot(df['pclass'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(df['sex'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(df['embarked'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='embarked', ylabel='count'>

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.countplot(df['pclass'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.distplot(df['fare'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.barplot(data=df,x='pclass', y='sex', hue='survived')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='sex'>

# %% [markdown]
# ## Data preprocessing

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Drop the columns

# %%
df=df.drop(columns=['deck', 'alive', 'alone','who','embark_town','class'],axis=1)

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch      fare  embarked  adult_male
# 0         0       3    1  22.0      1      0  2.110213         2           1
# 1         1       1    0  38.0      1      0  4.280593         0           0
# 2         1       3    0  26.0      0      0  2.188856         2           0
# 3         1       1    0  35.0      1      0  3.990834         2           0
# 4         0       3    1  35.0      0      0  2.202765         2           1

# %%
df.shape
# Out:
# (891, 9)

# %% [markdown]
# ## Fill missing values

# %%
df['age'].mean()
# Out:
# 29.699117647058763

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df['embarked'].value_counts()
# Out:
# 2    646
# 0    168
# 1     77
# Name: embarked, dtype: int64

# %%
df['embarked'].mode()[0]
# Out:
# 2

# %%
df['embarked']=df['embarked'].fillna(df['embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# adult_male    0
# dtype: int64

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])

# %%
df['embarked']=le.fit_transform(df['embarked'])

# %%
df['adult_male']=le.fit_transform(df['adult_male'])

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch      fare  embarked  adult_male
# 0         0       3    1  22.0      1      0  2.110213         2           1
# 1         1       1    0  38.0      1      0  4.280593         0           0
# 2         1       3    0  26.0      0      0  2.188856         2           0
# 3         1       1    0  35.0      1      0  3.990834         2           0
# 4         0       3    1  35.0      0      0  2.202765         2           1

# %% [markdown]
# ## Log transformation for uniform data distribution

# %%
sns.distplot(df['fare'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
df['fare']=np.log(df['fare']+1)

# %%
sns.distplot(df['fare'])
# Out:
# C:\Users\May Thazin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %% [markdown]
# # Correlation Matrix

# %%
corr=df.corr()

# %%
print(corr)
# Out:
#             survived    pclass       sex       age     sibsp     parch  \
# survived    1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# pclass     -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# sex        -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# age        -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# sibsp      -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# parch       0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# fare        0.303569 -0.535704 -0.253906  0.075312  0.300035  0.308772
# embarked   -0.167675  0.162098  0.108262 -0.026749  0.068230  0.039798
# adult_male -0.557080  0.094035  0.908578  0.253236 -0.253586 -0.349943
#
#                 fare  embarked  adult_male
# survived    0.303569 -0.167675   -0.557080
# pclass     -0.535704  0.162098    0.094035
# sex        -0.253906  0.108262    0.908578
# age         0.075312 -0.026749    0.253236
# sibsp       0.300035  0.068230   -0.253586
# parch       0.308772  0.039798   -0.349943
# fare        1.000000 -0.179881   -0.288951
# embarked   -0.179881  1.000000    0.092526
# adult_male -0.288951  0.092526    1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    int64
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    int64
#  8   adult_male  891 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 62.8 KB

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns=['survived'])
Y=df['survived']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=4)

# %%
print(X.shape)
print(X_train.shape)
# Out:
# (891, 8)
# (712, 8)

# %% [markdown]
# ## Model Training

# %%
def classify(model):
    model.fit(X_train,Y_train)
    print("accuracy",model.score(X_test,Y_test))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
classify(model)
# Out:
# accuracy 0.8547486033519553

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
classify(model)
# Out:
# accuracy 0.8603351955307262

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=4)
classify(model)
# Out:
# accuracy 0.8156424581005587
# C:\Users\May Thazin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
classify(model)
# Out:
# accuracy 0.8547486033519553

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model)
# Out:
# accuracy 0.8212290502793296
